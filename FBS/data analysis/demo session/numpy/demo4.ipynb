# %%
import numpy as np

# %%
np.random.random()
# Out:
# array([0.3101464 , 0.32408148, 0.0607731 , 0.15249211, 0.53358874,
#        0.58185194, 0.56750431, 0.75506703, 0.67565762, 0.50104829])

# %%
team1=np.random.randint(0,36,20)
team1
# Out:
# array([24,  4,  9,  3, 24, 19, 25, 20, 27, 20, 21, 26, 17, 26, 10,  1, 15,
#        35,  6, 11], dtype=int32)

# %%
np.random.randint(0,36,(4,3))
# Out:
# array([[29,  3, 16],
#        [27,  7, 26],
#        [ 6,  8, 12],
#        [12, 24, 19]], dtype=int32)

# %%
np.random.seed(75)
np.random.randint(0,100,1)
# Out:
# array([19], dtype=int32)

# %%
np.random.rand()
# Out:
# 0.7563298857816358

# %%
np.random.randn(10)
# Out:
# array([-1.37925852, -1.26922007,  2.98437224,  0.04038575, -0.67221661,
#         0.38703737,  2.39680022,  0.68111417,  1.4500866 , -2.09265058])

# %%
dice=np.arange(1,7)

# %%
np.random.choice(dice,1)
# Out:
# array([5])

# %%
dice
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.random.permutation(dice)
# Out:
# array([6, 1, 5, 4, 2, 3])

# %%
np.sin(np.radians(30))
# Out:
# np.float64(0.49999999999999994)

# %%
np.radians(np.sin(3*3.14))
# Out:
# np.float64(8.339082966900845e-05)

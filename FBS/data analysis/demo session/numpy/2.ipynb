# %%
import random
li1=[]
li2=[]
li3=[]
N=100000

# %%
for i in range(1,100001):
    li1.append(i)
for j in range(N):
    li2.append(random.randint(1, N+1))

for i in li1:
    for j in li2:
        li3.append(i+j)    
print(li3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       6 for i in li1:
#       7     for j in li2:
# ----> 8         li3.append(i+j)
#       9 print(li3)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lineplot
# 1.Trends over time
#
# 2.Time seies analysis
#
# 3.Upward/Downward trend

# %%
import numpy as np

# %%
overs=np.arange(1,21)
team_1=np.random.randint(0,37,20)
team_2=np.random.randint(0,37,20)
team_1,team_2
# Out:
# (array([11, 10, 11, 16,  0, 36, 30, 29, 32,  6,  5, 18,  6, 12, 18, 13, 31,
#          0,  7, 20], dtype=int32),
#  array([24, 30, 34, 35, 27, 31, 14,  3, 36, 36, 22, 35, 32, 32, 16, 26, 17,
#         16, 12, 32], dtype=int32))

# %%
team1_score=np.cumsum(team_1)
team1_score
# Out:
# array([ 11,  21,  32,  48,  48,  84, 114, 143, 175, 181, 186, 204, 210,
#        222, 240, 253, 284, 284, 291, 311])

# %%
team2_score=np.cumsum(team_2)
team2_score
# Out:
# array([ 24,  54,  88, 123, 150, 181, 195, 198, 234, 270, 292, 327, 359,
#        391, 407, 433, 450, 466, 478, 510])

# %%
plt.Figure(figsize=(7,3))
plt.style.use('dark_background')
plt.plot(overs,team1_score,marker='o',color='red',label='team1')
plt.plot(overs,team2_score,marker='>',color='blue',label='team2')
plt.xlabel('Overs')
plt.ylabel('Score')
plt.title('Match summary')
plt.legend()
plt.show()

# %% [markdown]
# ## Scatterplot
# 1. Relationship betn two variables
#
# 2. correlation
#
# 3. positive correlation
#
# 4. negative correlation

# %%
plt.Figure(figsize=(7,3))
plt.scatter(overs,team_1,color='red',marker='o',label='team1')
plt.scatter(overs,team_2,color='blue',marker='>',label='team2')
plt.legend()
plt.show()

# %% [markdown]
# ## Piechart
# 1. Showing percentage distribution
#
# 2. part to whole comparison
#
# 3. Best to use when categories<=5

# %%
marks=[70,90,67,40,76,72]
subjects=['m1','m2','m3','m4','m5','m6']

# %%
plt.pie(marks,labels=subjects,autopct='%0.2f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Boxplot
# 1. Summary of distribution
#
# 2. Check Outlier

# %%
plt.Figure(figsize=(7,3))
age=[1,2,3,4,5,6,7,8,14]
plt.boxplot(age)
plt.show()

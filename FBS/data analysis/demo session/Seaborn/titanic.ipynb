# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/HP/Downloads/titanic/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
med_age=df['Age'].median()

# %%
df['Age']=df['Age'].fillna(med_age)

# %%
df['Cabin']=df['Cabin'].fillna('Unknown')

# %%
df['Embarked']=df['Embarked'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].hist(df['Age'], bins=20)
ax[0].set_xlabel('Age')
ax[0].set_ylabel('Number of Passengers')
ax[0].set_title('Age Distribution')

ax[1].hist(df['Fare'], bins=20)
ax[1].set_xlabel('Fare')
ax[1].set_ylabel('Number of Passengers')
ax[1].set_title('Fare Distribution')

plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, x='Survived', hue='Sex')

plt.xlabel('Survival Status')
plt.ylabel('Number of Passengers')
plt.title('Survival by Sex')


plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
axes = axes.flatten()

# Features to compare against 'Survived'
features = ['Age', 'Fare', 'Pclass', 'SibSp', 'Parch']

for i, col in enumerate(features):
    # Changed boxplot to barplot
    sns.barplot(data=df, x='Survived', y=col, ax=axes[i], palette='Set2', errorbar='sd') 
    # errorbar='sd' shows standard deviation instead of confidence interval (optional)
    
    axes[i].set_title(f'Average {col} vs. Survival', fontsize=12, fontweight='bold')
    axes[i].set_xlabel('Survived (0 = Died, 1 = Survived)')
    axes[i].set_ylabel(f'Average {col}')

# Hide the 6th empty subplot
axes[5].set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_30092\1514322233.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Survived', y=col, ax=axes[i], palette='Set2', errorbar='sd')
# C:\Users\HP\AppData\Local\Temp\ipykernel_30092\1514322233.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Survived', y=col, ax=axes[i], palette='Set2', errorbar='sd')
# C:\Users\HP\AppData\Local\Temp\ipykernel_30092\1514322233.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
df['age_group'] = pd.cut(df['Age'], bins=[0, 12, 18, 40, 80], labels=['Child','Teen','Adult','Senior'])

sns.countplot(data=df, x='age_group', hue='Survived')
plt.title('Survival Count by Age Group')
plt.show()

# %%
# Calculate survival percentage within each age group
age_survival = df.groupby('age_group')['Survived'].mean() * 100

# Plot as a bar chart
plt.figure(figsize=(6, 4))
age_survival.sort_values().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Survival Rate by Age Group (%)')
plt.ylabel('Survival Percentage')
plt.xlabel('Age Group')
plt.ylim(0, 100)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_30092\2185897966.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_survival = df.groupby('age_group')['Survived'].mean() * 100
